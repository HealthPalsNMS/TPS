# %% [markdown]
# <a href="https://colab.research.google.com/github/HealthPalsNMS/TPS/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6519b4dd-f65e-49ec-82c5-d95b11edad8c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6519b4dd-f65e-49ec-82c5-d95b11edad8c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['Dataset (1) - Sheet1 (1).csv']))

# %%
df.head()
# Out:
#     Patient Name Date_of_checkup Date of recheckup             Checked By  \
# 0   Aanya Kapoor      2024-02-29               NIL   Dr.Shubham Tendulkar
# 1   Aariya Gupta      2024-01-12        2024-01-15       Dr. Gaurav Vijay
# 2  Aarthi Sharma      2024-03-20               NIL    Dr.Sumit Maheshwari
# 3   Aarti Sharma      2024-02-07        2024-02-12      Dr. Robert Kakkad
# 4    Abhay Arora      2024-01-23        2024-01-30  Dr. Shubham Tendulkar
#
#               Disease Fever Cough Fatigue Difficulty in Breathing  Age  \
# 0           Influenza   Yes    No     Yes                     Yes   19
# 1              Stroke    No   Yes     Yes                      No   55
# 2         Common Cold    No   Yes     Yes                      No   25
# 3  Multiple Sclerosis   Yes    No      No                      No   45
# 4          Bronchitis    No    No     Yes                     Yes   55
#
#    Gender  Blood Pressure*  Cholesterol Level  Fee
# ...

# %%
df.shape
# Out:
# (299, 14)

# %%
dataPatient50andAbove = df[df.Age > 50]

# %%
dataPatient50andAbove
# Out:
#            Patient Name Date_of_checkup Date of recheckup  \
# 1          Aariya Gupta      2024-01-12        2024-01-15
# 4           Abhay Arora      2024-01-23        2024-01-30
# 7        Abhimanyu Basu      2024-01-04        2024-01-08
# 15         Aditya Anand      2024-02-10        2024-02-13
# 26     Akash Chatterjee      2024-03-08               NIL
# 31        Akshay Dhawan      2024-01-09        2024-01-10
# 41        Amitabh Ghosh      2024-03-19        2024-03-26
# 59         Ayush Jindal      2024-03-10        2024-03-20
# 63        Bharat Kapoor      2024-02-01        2024-02-07
# 65        Bhaskar Kohli      2024-03-13        2024-03-22
# 69     Chandraksh Mehra      2024-03-14        2024-03-26
# 74       Darshan Mishra      2024-03-14        2024-03-23
# 76        Deepika Suri       2024-01-29        2024-02-06
# 79         Devansh Nair      2024-01-29        2024-02-02
# 80    Devika Maheshwari      2024-01-29        2024-02-08
# ...

# %%
dataPatient50andAbove.head()
# Out:
#         Patient Name Date_of_checkup Date of recheckup             Checked By  \
# 1       Aariya Gupta      2024-01-12        2024-01-15       Dr. Gaurav Vijay
# 4        Abhay Arora      2024-01-23        2024-01-30  Dr. Shubham Tendulkar
# 7     Abhimanyu Basu      2024-01-04        2024-01-08  Dr. Shubham Tendulkar
# 15      Aditya Anand      2024-02-10        2024-02-13       Dr.Vineeta Singh
# 26  Akash Chatterjee      2024-03-08               NIL    Dr.Sumit Maheshwari
#
#         Disease Fever Cough Fatigue Difficulty in Breathing  Age  Gender  \
# 1        Stroke    No   Yes     Yes                      No   55  Female
# 4    Bronchitis    No    No     Yes                     Yes   55    Male
# 7    Bronchitis   Yes   Yes     Yes                     Yes   55    Male
# 15       Anemia   Yes    No     Yes                      No   55    Male
# 26  Common Cold   Yes    No     Yes                     Yes   55    Male
#
#     Blood Pressure*  Cholesterol Level  Fee
# ...

# %%
dfFee700andAbove = df[df.Fee > 700]

# %%
dfFee700andAbove
# Out:
#       Patient Name Date_of_checkup Date of recheckup          Checked By  \
# 166  Mahika Kapoor      2024-01-15        2024-02-04  Dr.Shubman Gajawat
#
#                         Disease Fever Cough Fatigue Difficulty in Breathing  \
# 166  Hypertensive Heart Disease    No    No     Yes                      No
#
#      Age  Gender  Blood Pressure*  Cholesterol Level  Fee
# 166   30  Female                3                  3  750

# %%
# !pip install torch
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# ...

# %%
# !pip install torchvision

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
df.describe()
# Out:
#               Age  Blood Pressure*  Cholesterol Level         Fee
# count  299.000000       299.000000         299.000000  299.000000
# mean    42.481605         2.401338           2.331104  381.672241
# std      9.877547         0.601562           0.661046   69.344096
# min     15.000000         1.000000           1.000000  300.000000
# 25%     35.000000         2.000000           2.000000  350.000000
# 50%     42.000000         2.000000           2.000000  350.000000
# 75%     50.000000         3.000000           3.000000  385.000000
# max     60.000000         3.000000           3.000000  750.000000

# %%
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
# Split the data into features and target
x=('Age',axis=1), data=df
y=('Fee'), data=df
# Out:
#   File "<ipython-input-31-8fe179aadd5a>", line 2
#     x=('Age',axis=1), data=df
#              ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
sns.lmplot(x='Age' ,y='Cholesterol Level', data=df)

# %%
Create and train the linear regression model
model = LinearRegression()
model.fit(X, y)

# Make predictions
predictions = model.predict(X)
